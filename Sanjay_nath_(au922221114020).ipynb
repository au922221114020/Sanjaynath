# %% [markdown]
# <a href="https://colab.research.google.com/github/au922221114020/Sanjaynath/blob/main/Sanjay_nath_(au922221114020).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


dataset_train = pd.read_csv('https://raw.githubusercontent.com/AMoazeni/Machine-Learning-Stock-Market-Prediction/master/Data/Google_Stock_Price_Train.csv')

training_set = dataset_train.iloc[:, 1:2].values


from sklearn.preprocessing import MinMaxScaler

sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

X_train = []

y_train = []
for i in range(60, 1258):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)


X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))


display(dataset_train)


from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout


regressor = Sequential()

regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))

regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

regressor.fit(X_train, y_train, epochs = 50, batch_size = 40)


dataset_test = pd.read_csv('https://raw.githubusercontent.com/AMoazeni/Machine-Learning-Stock-Market-Prediction/master/Data/Google_Stock_Price_Test.csv')
real_stock_price = dataset_test.iloc[:, 1:2].values


dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)

inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values

inputs = inputs.reshape(-1,1)

inputs = sc.transform(inputs)

X_test = []

for i in range(60, 80):
    X_test.append(inputs[i-60:i, 0])

X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

predicted_stock_price = regressor.predict(X_test)

predicted_stock_price = sc.inverse_transform(predicted_stock_price)

plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
# Out:
#             Date    Open    High     Low   Close      Volume
# 0       1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1       1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2       1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3       1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4       1/9/2012  322.04  322.29  309.46  620.76  11,688,800
# ...          ...     ...     ...     ...     ...         ...
# 1253  12/23/2016  790.90  792.74  787.28  789.91     623,400
# 1254  12/27/2016  790.68  797.86  787.66  791.55     789,100
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1,153,800
# 1256  12/29/2016  783.33  785.93  778.92  782.79     744,300
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 6 columns]
# Epoch 1/50
# 30/30 [==============================] - 23s 106ms/step - loss: 0.0499
# Epoch 2/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0095
# Epoch 3/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0063
# Epoch 4/50
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0056
# Epoch 5/50
# 30/30 [==============================] - 3s 106ms/step - loss: 0.0054
# Epoch 6/50
# 30/30 [==============================] - 3s 106ms/step - loss: 0.0060
# Epoch 7/50
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0055
# Epoch 8/50
# 30/30 [==============================] - 4s 116ms/step - loss: 0.0043
# Epoch 9/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0050
# Epoch 10/50
# 30/30 [==============================] - 3s 105ms/step - loss: 0.0045
# Epoch 11/50
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0043
# Epoch 12/50
# 30/30 [==============================] - 3s 106ms/step - loss: 0.0040
# Epoch 13/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0044
# Epoch 14/50
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0041
# Epoch 15/50
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0041
# Epoch 16/50
# 30/30 [==============================] - 3s 108ms/step - loss: 0.0040
# Epoch 17/50
# 30/30 [==============================] - 5s 176ms/step - loss: 0.0038
# Epoch 18/50
# 30/30 [==============================] - 6s 185ms/step - loss: 0.0038
# Epoch 19/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0047
# Epoch 20/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0037
# Epoch 21/50
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0039
# Epoch 22/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0035
# Epoch 23/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0035
# Epoch 24/50
# 30/30 [==============================] - 3s 114ms/step - loss: 0.0036
# Epoch 25/50
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0038
# Epoch 26/50
# 30/30 [==============================] - 3s 106ms/step - loss: 0.0039
# Epoch 27/50
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0035
# Epoch 28/50
# 30/30 [==============================] - 5s 161ms/step - loss: 0.0037
# Epoch 29/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0032
# Epoch 30/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0029
# Epoch 31/50
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0033
# Epoch 32/50
# 30/30 [==============================] - 4s 122ms/step - loss: 0.0032
# Epoch 33/50
# 30/30 [==============================] - 3s 108ms/step - loss: 0.0029
# Epoch 34/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0031
# Epoch 35/50
# 30/30 [==============================] - 5s 181ms/step - loss: 0.0033
# Epoch 36/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0028
# Epoch 37/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0032
# Epoch 38/50
# 30/30 [==============================] - 4s 121ms/step - loss: 0.0029
# Epoch 39/50
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0032
# Epoch 40/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0029
# Epoch 41/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0030
# Epoch 42/50
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0028
# Epoch 43/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0025
# Epoch 44/50
# 30/30 [==============================] - 3s 109ms/step - loss: 0.0030
# Epoch 45/50
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0032
# Epoch 46/50
# 30/30 [==============================] - 4s 132ms/step - loss: 0.0028
# Epoch 47/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0025
# Epoch 48/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0027
# Epoch 49/50
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0025
# Epoch 50/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0027
# 1/1 [==============================] - 2s 2s/step
